# %% [markdown]
# # **Q.1 What is K-Nearest Neighbors (KNN) and how does it work**

# %%
# K-Nearest Neighbors (KNN) is a simple and widely used supervised machine learning algorithm used for classification and regression tasks.
# It works by finding the "K" training examples that are closest to a new data point and then making a prediction based on those neighbors.

# How does it work :-
# 1.Choose the number of neighbors
# 2.Calculate distances
# 3.Find the nearest neighbors
# 4.Make predictions

# %% [markdown]
# # Q.2  What is the difference between KNN Classification and KNN Regression.

# %%
# 1. KNN Classification:
# Purpose: Used for categorical outcomes or classes
# Classifying objects into discrete categories, like identifying whether an email is spam or not, or recognizing whether an animal is a "dog," "cat," or "bird."

# 2. KNN Regression:
# Purpose: Used for continuous outcomes or numerical predictions
# Predicting continuous values, such as house prices, stock prices, or the temperature of a location.

# %% [markdown]
# # **Q>3 What is the role of the distance metric in KNN.**

# %%
# The distance metric plays a crucial role in the K-Nearest Neighbors (KNN) algorithm, as it determines how the "closeness" or "similarity"
# between data points is calculated. KNN relies on this metric to find the nearest neighbors to a given test point,
# and the quality of the predictions is highly dependent on the choice of distance metric.

# ROLE:
# 1.Determining the Nearest Neighbors
# 2.Influencing Prediction Accuracy
# 3.Handling Different Feature Types
# 4.Dealing with the "Curse of Dimensionality"

# %% [markdown]
# # **Q.4 What is the Curse of Dimensionality in KNN**

# %%
# The Curse of Dimensionality refers to the phenomenon where the performance of a machine learning algorithm,
# including K-Nearest Neighbors (KNN), degrades as the number of features (or dimensions) in the dataset increases.
# This occurs because the distance between data points becomes less informative or meaningful as the number of dimensions grows.

# %% [markdown]
# # **Q.5 How can we choose the best value of K in KNN.**

# %%
# Choosing the best value of K (the number of neighbors) in K-Nearest Neighbors (KNN) is critical to the model's performance.
# The value of 𝐾 determines how many of the nearest neighbors are considered when making a prediction.

# Selecting a suitable  𝐾 value is important because it directly affects the model's ability to generalize from the training data to new, unseen data.

# %% [markdown]
# # **Q.6  What are KD Tree and Ball Tree in KNN.**

# %%
# 1. KD-Tree (K-Dimensional Tree)
# KD-Tree is a space-partitioning data structure that organizes data points in a k-dimensional space. It's useful for low- to medium-dimensional data.
# The KD-Tree recursively splits the data based on the values of different features (dimensions) to create a tree-like structure.

# 2. Ball Tree
# Ball Tree is another data structure for organizing data points, particularly effective in high-dimensional spaces.
# It’s based on partitioning the data into balls (hyper-spheres) rather than hyper-rectangles (as in KD-Trees).

# %% [markdown]
# # **Q.7 When should you use KD Tree vs. Ball Tree**

# %%
# 1. Use KD-Tree When :-

# >Low to Moderate Dimensionality
# >Features Are Correlated or Have Simple Structures
# >Smaller Datasets
# >You Need Faster Queries in Low Dimensions

# 2. Use Ball Tree When:-

#> High Dimensionality
# > Complex, Non-Rectangular Data Distributions
# > Large Datasets or Complex Data Structures
# > Data Has Outliers or Irregular Distributions

# %% [markdown]
# # **Q.8 What are the disadvantages of KNN**

# %%
# 1. Computationally Expensive
# 2. Curse of Dimensionality
# 3. Memory Intensive
# 4. Sensitivity to Irrelevant or Redundant Features
# 5. . Effectiveness with Imbalanced Datasets

# %% [markdown]
# # **Q.9 How does feature scaling affect KNN**

# %%
# Here's how scaling affects KNN :

# 1. Distance Sensitivity
# 2. Improved Accuracy
# 3. Types of Scaling
# 4. Effects Without Scaling :
# If scaling is not performed, KNN may give biased results because the distance calculation will be dominated by high-magnitude features.

# %% [markdown]
# # **Q.10 What is PCA (Principal Component Analysis).**

# %%
# Principal Component Analysis (PCA) is a statistical technique used for dimensionality reduction while preserving as much of the data's variability as possible.
# It transforms the original features of a dataset into a new set of variables called principal components.
# These components are linear combinations of the original features, ordered by the amount of variance they explain in the data.

# %% [markdown]
# # **Q.11 How does PCA work.**

# %%
# Here’s how PCA works:

# 1. Goal:
# The main goal of PCA is to reduce the number of features (dimensions) in a dataset while retaining as much information (variance) as possible.
# 2. Steps in PCA:
# > Standardize the Data: Since PCA is sensitive to the scale of the data, the first step is usually to standardize the features.
# > Compute the Covariance Matrix: The covariance matrix represents the relationships between the features, showing how the features co-vary with each other
# > Calculate Eigenvectors and Eigenvalues: Eigenvectors represent the directions (principal components) along which the data varies the most,
# and eigenvalues indicate the amount of variance explained by each principal component.
# 3. Key Concepts:
# Principal Components: These are the new axes (directions) in the feature space that capture the maximum variance in the data.

# %% [markdown]
# # **Q.12 What is the geometric intuition behind PCA.**

# %%
# The geometric intuition behind Principal Component Analysis (PCA) revolves around finding new axes (directions) in the data space along which the data has the most variation.
# These new axes, known as principal components, allow us to represent the data in a lower-dimensional space while retaining as much of its structure as possible.

# %% [markdown]
# # **Q.13 What is the difference between Feature Selection and Feature Extraction.**

# %%
# 1. Feature Selection:
# Goal: The goal of feature selection is to select a subset of the original features that are most relevant to the task at hand.

# How It Works: In feature selection, you keep the original features and choose only a subset of them based on their importance or relevance to the model.

# 2. Feature Extraction:
# Goal: The goal of feature extraction is to transform the original features into a new set of features that better represent the underlying structure or patterns in the data.

# How It Works: Feature extraction creates new features by combining, transforming, or projecting the original features.

# %% [markdown]
# # **Q.14 What are Eigenvalues and Eigenvectors in PCA.**

# %%
# 1. Eigenvectors:
# Eigenvectors represent the directions in which the data varies the most .

# In PCA, each eigenvector corresponds to a principal component of the data.

# 2. Eigenvalues:
# Eigenvalues quantify the amount of variance captured by their corresponding eigenvectors.

# Larger eigenvalues indicate that the corresponding principal component captures a higher variance of the data,
# meaning it's more important in terms of explaining the variation in the dataset.

# %% [markdown]
# # **Q.15 How do you decide the number of components to keep in PCA**

# %%
# Each principal component (PC) captures a certain amount of the variance in the data. To decide how many components to keep,
# we look at how much variance each component explains and choose the smallest number of components that explain a sufficient amount of the total variance.

# A Scree plot is a graphical representation of the eigenvalues (or explained variance) of each principal component.

# According to Kaiser’s Criterion, you should keep only those components whose eigenvalue is greater than 1.

# The idea behind this is that a component with an eigenvalue smaller than 1 explains less variance than a single feature, so it’s not considered worth keeping.

# %% [markdown]
# # **Q.16 Can PCA be used for classification**

# %%
# es, Principal Component Analysis (PCA) can be used as a preprocessing step for classification, but it is not a classification technique by itself.
# PCA is primarily a dimensionality reduction technique, meaning it helps reduce the number of features
# in the dataset while retaining as much of the variance (information) as possible.

# %% [markdown]
# # Q.17 What are the limitations of PCA

# %%
#  Here are some of the key limitations of PCA:

#  1. Linearity Assumption
#  2. Sensitivity to Scaling
#  3. Interpretability of Components
#  4. Loss of Information

# %% [markdown]
# # **Q.18 How do KNN and PCA complement each other.**

# %%
# 1. Dimensionality Reduction with PCA:
# PCA is a technique used for dimensionality reduction, where it transforms high-dimensional data into a
# lower-dimensional space while preserving as much variance as possible.

# KNN, on the other hand, is a distance-based classifier. It works by calculating the distances
# between a data point and its neighbors to determine its class.

# 2. Noise Reduction and Feature Selection:
# PCA can help filter out noisy features or irrelevant dimensions, as it focuses on the directions
# of the most significant variance in the data.

# By retaining only the most important principal components, PCA removes noise from the data, which can improve KNN's performance.

# 3. Handling High-Dimensional Data:
# Many real-world datasets have a large number of features (e.g., image data or text data after one-hot encoding).
# KNN in such high-dimensional datasets can be very inefficient and suffer from the curse of dimensionality,
# where the distances between points become almost equal, making the classification task harder.

# By applying PCA to reduce the dimensionality, you can significantly improve the performance and efficiency of KNN,
# because the data will now lie in a lower-dimensional space where distances are more meaningful.

# %% [markdown]
# # **Q.19 How does KNN handle missing values in a dataset ?**

# %%
# K-Nearest Neighbors (KNN) doesn't directly handle missing values in a dataset; however,
# there are several common strategies to manage missing data before applying the KNN algorithm.

# 1. Imputation (Filling in the Missing Values)
# One common approach is to impute the missing values before applying KNN.
# 2. Removing Missing Values
# 3. Using Similarity-based Methods for Imputation
# 4. Using KNN with Distance-Based Approaches

# %% [markdown]
# ## **Q.20 What are the key differences between PCA and Linear Discriminant Analysis (LDA).**

# %%
# 1. Purpose :

# PCA:

# Unsupervised technique: PCA is a technique used for dimensionality reduction that seeks to find a lower-dimensional representation
# of the data while retaining as much variance (information) as possible.

# Maximizes variance: PCA aims to project the data onto directions (principal components) that capture the maximum variance, without considering class labels.

# LDA :

# Supervised technique: LDA is a supervised technique for dimensionality reduction, meaning it takes into account the class labels in the data.

# Maximizes class separability: LDA seeks to find a lower-dimensional representation that maximizes the separation between multiple classes.

# 2. Type of Data:
# PCA:

# Works with unlabeled data: PCA does not require class labels for the data.
# It is applied to any dataset to reduce dimensions based on the variance of the features,
# making it suitable for exploratory data analysis or feature extraction in unsupervised learning tasks.

# LDA:

# Requires labeled data: LDA is a supervised technique, which means it requires labeled data .
# It uses these labels to guide the dimensionality reduction process.

# 3. Goal:
# PCA:

# Maximizes variance: The main goal of PCA is to transform the data into a new set of orthogonal (uncorrelated) features
# that capture as much of the variance in the data as possible. It does not specifically try to improve class separability.

# LDA:

# Maximizes class separability: LDA tries to find a projection of the data that maximizes the separation between classes.
# It does so by maximizing the between-class scatter while minimizing the within-class scatter

# %% [markdown]
# # **Q.21 Train a KNN Classifier on the Iris dataset and print model accuracy.**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Load Iris dataset
iris = load_iris()
X, y = iris.data, iris.target

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize KNN classifier with k=3
knn = KNeighborsClassifier(n_neighbors=3)

# Train the model
knn.fit(X_train, y_train)

# Predict on the test set
y_pred = knn.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f"Model accuracy: {accuracy:.2f}")
# Out:
# Model accuracy: 1.00

# %% [markdown]
# # **Q.22 Train a KNN Regressor on a synthetic dataset and evaluate using Mean Squared Error (MSE).**

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

# Generate synthetic regression dataset
X, y = make_regression(n_samples=200, n_features=1, noise=15, random_state=42)

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and train KNN Regressor
knn_regressor = KNeighborsRegressor(n_neighbors=5)
knn_regressor.fit(X_train, y_train)

# Predict on test data
y_pred = knn_regressor.predict(X_test)

# Evaluate using Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error (MSE): {mse:.2f}")
# Out:
# Mean Squared Error (MSE): 522.32

# %% [markdown]
# # **Q.23  Train a KNN Classifier using different distance metrics (Euclidean and Manhattan) and compare accuracy**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Load Iris dataset
iris = load_iris()
X, y = iris.data, iris.target

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Define distance metrics
metrics = {
    "Euclidean": "euclidean",
    "Manhattan": "manhattan"
}

# Train and evaluate KNN with each metric
for name, metric in metrics.items():
    knn = KNeighborsClassifier(n_neighbors=3, metric=metric)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print(f"{name} distance - Accuracy: {accuracy:.2f}")
# Out:
# Euclidean distance - Accuracy: 1.00
# Manhattan distance - Accuracy: 1.00

# %% [markdown]
# # **Q.24  Train a KNN Classifier with different values of K and visualize decision boundaried**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# Load Iris dataset and use only two features for 2D visualization
iris = load_iris()
X = iris.data[:, :2]  # only the first two features (sepal length and width)
y = iris.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.3)

# Meshgrid creation for decision boundary visualization
h = .02  # step size in the mesh
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
                     np.arange(y_min, y_max, h))

# Values of k to visualize
k_values = [1, 5, 15]

plt.figure(figsize=(18, 5))

for i, k in enumerate(k_values):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    # Plotting
    plt.subplot(1, len(k_values), i + 1)
    plt.contourf(xx, yy, Z, alpha=0.4, cmap=plt.cm.coolwarm)
    plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, edgecolor='k', cmap=plt.cm.coolwarm, label='Train')
    plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, marker='*', s=100, edgecolor='k', cmap=plt.cm.coolwarm, label='Test')
    plt.title(f"K = {k}")
    plt.xlabel("Sepal Length")
    plt.ylabel("Sepal Width")
    plt.legend()

plt.suptitle("KNN Decision Boundaries with Different Values of K", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Q.25 Apply Feature Scaling before training a KNN model and compare results with unscaled data**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# Load dataset
iris = load_iris()
X, y = iris.data, iris.target

# Split into train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# --- Without Feature Scaling ---
knn_unscaled = KNeighborsClassifier(n_neighbors=5)
knn_unscaled.fit(X_train, y_train)
y_pred_unscaled = knn_unscaled.predict(X_test)
accuracy_unscaled = accuracy_score(y_test, y_pred_unscaled)

# --- With Feature Scaling ---
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

knn_scaled = KNeighborsClassifier(n_neighbors=5)
knn_scaled.fit(X_train_scaled, y_train)
y_pred_scaled = knn_scaled.predict(X_test_scaled)
accuracy_scaled = accuracy_score(y_test, y_pred_scaled)

# Print results
print(f"Accuracy WITHOUT scaling: {accuracy_unscaled:.2f}")
print(f"Accuracy WITH scaling   : {accuracy_scaled:.2f}")
# Out:
# Accuracy WITHOUT scaling: 1.00
# Accuracy WITH scaling   : 1.00

# %% [markdown]
# # **Q.26 Train a PCA model on synthetic data and print the explained variance ratio for each component**

# %%
from sklearn.datasets import make_classification
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np

# Generate synthetic data
X, y = make_classification(n_samples=300, n_features=5, n_informative=3, n_redundant=0, random_state=42)

# Apply PCA
pca = PCA()
X_pca = pca.fit_transform(X)

# Print explained variance ratio
explained_variance = pca.explained_variance_ratio_
for i, ratio in enumerate(explained_variance):
    print(f"Principal Component {i+1}: {ratio:.4f}")
# Out:
# Principal Component 1: 0.4206
# Principal Component 2: 0.2200
# Principal Component 3: 0.1362
# Principal Component 4: 0.1239
# Principal Component 5: 0.0993

# %% [markdown]
# # **Q.27 Apply PCA before training a KNN Classifier and compare accuracy with and without PCA5**

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Generate synthetic data
X, y = make_classification(n_samples=500, n_features=5, n_informative=4, n_redundant=0, random_state=42)

# Split into train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the data before PCA and KNN
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# ----- KNN WITHOUT PCA -----
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)
y_pred = knn.predict(X_test_scaled)
accuracy_no_pca = accuracy_score(y_test, y_pred)

# ----- KNN WITH PCA (keep all 5 components) -----
pca = PCA(n_components=5)
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

knn_pca = KNeighborsClassifier(n_neighbors=5)
knn_pca.fit(X_train_pca, y_train)
y_pred_pca = knn_pca.predict(X_test_pca)
accuracy_with_pca = accuracy_score(y_test, y_pred_pca)

# Print results
print(f"Accuracy WITHOUT PCA: {accuracy_no_pca:.2f}")
print(f"Accuracy WITH PCA (5 components): {accuracy_with_pca:.2f}")

# Optional: print explained variance ratio
print("\nExplained Variance Ratio per Component:")
for i, ratio in enumerate(pca.explained_variance_ratio_):
    print(f"Component {i+1}: {ratio:.4f}")
# Out:
# Accuracy WITHOUT PCA: 0.83
# Accuracy WITH PCA (5 components): 0.83
#
# Explained Variance Ratio per Component:
# Component 1: 0.3412
# Component 2: 0.2088
# Component 3: 0.2004
# Component 4: 0.1548
# Component 5: 0.0948

# %% [markdown]
# # **Q.28 Perform Hyperparameter Tuning on a KNN Classifier using GridSearchCV**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# Load Iris dataset
iris = load_iris()
X, y = iris.data, iris.target

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create a pipeline: Scaling + KNN
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('knn', KNeighborsClassifier())
])

# Define hyperparameter grid
param_grid = {
    'knn__n_neighbors': [3, 5, 7, 9],
    'knn__weights': ['uniform', 'distance'],
    'knn__metric': ['euclidean', 'manhattan']
}

# Set up GridSearchCV
grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Best model and parameters
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validated Accuracy:", grid_search.best_score_)


# Evaluate on test data
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy:", test_accuracy)
# Out:
# Best Parameters: {'knn__metric': 'euclidean', 'knn__n_neighbors': 5, 'knn__weights': 'distance'}
# Best Cross-Validated Accuracy: 0.9428571428571428
# Test Accuracy: 1.0

# %% [markdown]
# # **Q.29 Train a KNN Classifier and check the number of misclassified samples**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Load dataset
iris = load_iris()
X, y = iris.data, iris.target

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train KNN
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

# Predict
y_pred = knn.predict(X_test_scaled)

# Count misclassified samples
misclassified = (y_test != y_pred).sum()
accuracy = accuracy_score(y_test, y_pred)

# Print results
print(f"Total test samples: {len(y_test)}")
print(f"Misclassified samples: {misclassified}")
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Total test samples: 45
# Misclassified samples: 0
# Accuracy: 1.00

# %% [markdown]
# # **Q.30 Train a PCA model and visualize the cumulative explained variance**

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Load dataset
iris = load_iris()
X = iris.data

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Fit PCA
pca = PCA()
pca.fit(X_scaled)

# Calculate cumulative explained variance
cumulative_variance = pca.explained_variance_ratio_.cumsum()

# Plot
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o', linestyle='--', color='b')
plt.title('Cumulative Explained Variance by PCA Components')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.grid(True)
plt.axhline(y=0.95, color='r', linestyle='--', label='95% Threshold')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Q.31 Train a KNN Classifier using different values of the weights parameter (uniform vs. distance) and compare accuracy**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Load Iris dataset
iris = load_iris()
X, y = iris.data, iris.target

# Split into train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define and train KNN with uniform weights
knn_uniform = KNeighborsClassifier(n_neighbors=5, weights='uniform')
knn_uniform.fit(X_train_scaled, y_train)
y_pred_uniform = knn_uniform.predict(X_test_scaled)
accuracy_uniform = accuracy_score(y_test, y_pred_uniform)

# Define and train KNN with distance weights
knn_distance = KNeighborsClassifier(n_neighbors=5, weights='distance')
knn_distance.fit(X_train_scaled, y_train)
y_pred_distance = knn_distance.predict(X_test_scaled)
accuracy_distance = accuracy_score(y_test, y_pred_distance)

# Print results
print(f"Accuracy with uniform weights: {accuracy_uniform:.2f}")
print(f"Accuracy with distance weights: {accuracy_distance:.2f}")
# Out:
# Accuracy with uniform weights: 1.00
# Accuracy with distance weights: 1.00

# %% [markdown]
# # **Q.32 Train a KNN Regressor and analyze the effect of different K values on performance**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

# Generate synthetic regression data
X, y = make_regression(n_samples=200, n_features=1, noise=15, random_state=42)

# Split into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# List of K values to test
k_values = [1, 5, 15, 30]

# Initialize a list to store MSE for each K
mse_values = []

# Loop over K values
for k in k_values:
    # Train KNN Regressor
    knn_regressor = KNeighborsRegressor(n_neighbors=k)
    knn_regressor.fit(X_train, y_train)

    # Predict on test data
    y_pred = knn_regressor.predict(X_test)

    # Calculate Mean Squared Error
    mse = mean_squared_error(y_test, y_pred)
    mse_values.append(mse)

    # Plot predictions for each K
    plt.figure(figsize=(8, 5))
    plt.scatter(X_test, y_test, color='blue', label='True Values')
    plt.scatter(X_test, y_pred, color='red', label=f'Predictions (K={k})')
    plt.title(f"KNN Regressor with K={k}")
    plt.xlabel("Feature")
    plt.ylabel("Target")
    plt.legend()
    plt.show()

# Plot MSE vs K values
plt.figure(figsize=(8, 5))
plt.plot(k_values, mse_values, marker='o', linestyle='-', color='b')
plt.title("Effect of K on KNN Regressor Performance (MSE)")
plt.xlabel("K (Number of Neighbors)")
plt.ylabel("Mean Squared Error")
plt.grid(True)
plt.show()

# Print MSE for each K
for k, mse in zip(k_values, mse_values):
    print(f"K = {k}, MSE = {mse:.2f}")
# Out:
# K = 1, MSE = 527.88
# K = 5, MSE = 522.32
# K = 15, MSE = 778.63
# K = 30, MSE = 1316.83

# %% [markdown]
# # **Q.33 Implement KNN Imputation for handling missing values in a datase**

# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer

# Create a sample dataset with missing values
data = {
    'Feature1': [1.0, 2.0, np.nan, 4.0, 5.0],
    'Feature2': [np.nan, 2.0, 3.0, np.nan, 5.0],
    'Feature3': [1.0, np.nan, 3.0, 4.0, 5.0]
}

df = pd.DataFrame(data)
print("Original Data with Missing Values:")
print(df)

# Initialize KNNImputer
imputer = KNNImputer(n_neighbors=2)  # Using 2 neighbors for imputation

# Apply KNN imputation
df_imputed = imputer.fit_transform(df)

# Convert the result back into a DataFrame
df_imputed = pd.DataFrame(df_imputed, columns=df.columns)

print("\nData After KNN Imputation:")
print(df_imputed)
# Out:
# Original Data with Missing Values:
#    Feature1  Feature2  Feature3
# 0       1.0       NaN       1.0
# 1       2.0       2.0       NaN
# 2       NaN       3.0       3.0
# 3       4.0       NaN       4.0
# 4       5.0       5.0       5.0
#
# Data After KNN Imputation:
#    Feature1  Feature2  Feature3
# 0       1.0       2.5       1.0
# 1       2.0       2.0       2.0
# 2       3.0       3.0       3.0
# 3       4.0       4.0       4.0
# 4       5.0       5.0       5.0

# %%
#Q.34 Train a PCA model and visualize the data projection onto the first two principal components

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

# Load Iris dataset
iris = load_iris()
X = iris.data
y = iris.target
target_names = iris.target_names

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA to reduce to 2 components
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Plot the projection onto the first two principal components
plt.figure(figsize=(8, 6))
colors = ['navy', 'turquoise', 'darkorange']
lw = 2

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    plt.scatter(X_pca[y == i, 0], X_pca[y == i, 1], color=color, alpha=0.8, lw=lw, label=target_name)

plt.title('PCA of Iris Dataset')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Q.35 Train a KNN Classifier using the KD Tree and Ball Tree algorithms and compare performance**

# %%
import time
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Load Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Define a function to train and evaluate KNN with different algorithms
def train_knn_with_algorithm(algorithm):
    # Initialize the KNN classifier with the specified algorithm
    knn = KNeighborsClassifier(n_neighbors=5, algorithm=algorithm)

    # Measure the training time
    start_time = time.time()
    knn.fit(X_train_scaled, y_train)
    training_time = time.time() - start_time

    # Predict on the test data
    y_pred = knn.predict(X_test_scaled)

    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)

    return accuracy, training_time

# Train KNN with KD-Tree
accuracy_kd, time_kd = train_knn_with_algorithm('kd_tree')

# Train KNN with Ball-Tree
accuracy_ball, time_ball = train_knn_with_algorithm('ball_tree')

# Print the results
print(f"KNN with KD-Tree Algorithm: Accuracy = {accuracy_kd:.2f}, Training Time = {time_kd:.4f} seconds")
print(f"KNN with Ball-Tree Algorithm: Accuracy = {accuracy_ball:.2f}, Training Time = {time_ball:.4f} seconds")
# Out:
# KNN with KD-Tree Algorithm: Accuracy = 1.00, Training Time = 0.0008 seconds
# KNN with Ball-Tree Algorithm: Accuracy = 1.00, Training Time = 0.0011 seconds

# %% [markdown]
# # **Q.36 Train a PCA model on a high-dimensional dataset and visualize the Scree plot**

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler

# Load the digits dataset (8x8 images flattened into 64 features)
digits = load_digits()
X = digits.data
y = digits.target

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train PCA and fit the scaled data
pca = PCA()
pca.fit(X_scaled)

# Explained variance ratio for each component
explained_variance_ratio = pca.explained_variance_ratio_

# Plot the Scree plot
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, marker='o', linestyle='--', color='b')
plt.title('Scree Plot of Digits Dataset (PCA)')
plt.xlabel('Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.grid(True)
plt.tight_layout()
plt.show()

# Optional: Plot Cumulative Explained Variance
cumulative_variance = explained_variance_ratio.cumsum()
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o', color='g')
plt.axhline(y=0.95, color='r', linestyle='--', label='95% Explained Variance')
plt.title('Cumulative Explained Variance of Digits Dataset (PCA)')
plt.xlabel('Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.legend(loc='best')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Q.37 Train a KNN Classifier and evaluate performance using Precision, Recall, and F1-Score

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train KNN Classifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

# Predict on test data
y_pred = knn.predict(X_test_scaled)

# Print classification report (Precision, Recall, F1-Score)
print("Classification Report:")
print(classification_report(y_test, y_pred, target_names=iris.target_names))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %% [markdown]
# # **Q.38 Train a PCA model and analyze the effect of different numbers of components on accuracy**

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Load the dataset
iris = load_iris()
X = iris.data
y = iris.target

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Test different numbers of PCA components
components_range = range(1, X.shape[1] + 1)
accuracies = []

for n_components in components_range:
    # Apply PCA
    pca = PCA(n_components=n_components)
    X_train_pca = pca.fit_transform(X_train)
    X_test_pca = pca.transform(X_test)

    # Train KNN classifier
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(X_train_pca, y_train)

    # Predict and evaluate accuracy
    y_pred = knn.predict(X_test_pca)
    acc = accuracy_score(y_test, y_pred)
    accuracies.append(acc)

# Plot Accuracy vs Number of PCA Components
plt.figure(figsize=(8, 5))
plt.plot(components_range, accuracies, marker='o', linestyle='--', color='b')
plt.title('Effect of PCA Components on KNN Accuracy')
plt.xlabel('Number of PCA Components')
plt.ylabel('Accuracy')
plt.grid(True)
plt.xticks(components_range)
plt.tight_layout()
plt.show()

# Print results
for n, acc in zip(components_range, accuracies):
    print(f"PCA Components: {n}, Accuracy: {acc:.2f}")
# Out:
# PCA Components: 1, Accuracy: 0.96
# PCA Components: 2, Accuracy: 0.96
# PCA Components: 3, Accuracy: 1.00
# PCA Components: 4, Accuracy: 1.00

# %% [markdown]
# # **Q 39Train a KNN Classifier with different leaf_size values and compare accuracy.**

# %%
import time
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# Load dataset
iris = load_iris()
X, y = iris.data, iris.target

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Define range of leaf_size values to test
leaf_sizes = [1, 5, 10, 20, 30, 50]
accuracies = []
times = []

# Train and evaluate for each leaf_size
for leaf in leaf_sizes:
    knn = KNeighborsClassifier(n_neighbors=5, leaf_size=leaf)

    start = time.time()
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    end = time.time()

    acc = accuracy_score(y_test, y_pred)
    accuracies.append(acc)
    times.append(end - start)

# Plot accuracy vs. leaf_size
plt.figure(figsize=(8, 5))
plt.plot(leaf_sizes, accuracies, marker='o', linestyle='--', label='Accuracy')
plt.xlabel('leaf_size')
plt.ylabel('Accuracy')
plt.title('KNN Accuracy vs. leaf_size')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# (Optional) Plot time vs. leaf_size
plt.figure(figsize=(8, 5))
plt.plot(leaf_sizes, times, marker='s', linestyle='--', color='orange', label='Training + Prediction Time')
plt.xlabel('leaf_size')
plt.ylabel('Time (s)')
plt.title('Training & Prediction Time vs. leaf_size')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# Print Results
for leaf, acc, t in zip(leaf_sizes, accuracies, times):
    print(f"leaf_size: {leaf}, Accuracy: {acc:.2f}, Time: {t:.4f} seconds")
# Out:
# leaf_size: 1, Accuracy: 1.00, Time: 0.0044 seconds
# leaf_size: 5, Accuracy: 1.00, Time: 0.0040 seconds
# leaf_size: 10, Accuracy: 1.00, Time: 0.0060 seconds
# leaf_size: 20, Accuracy: 1.00, Time: 0.0038 seconds
# leaf_size: 30, Accuracy: 1.00, Time: 0.0036 seconds
# leaf_size: 50, Accuracy: 1.00, Time: 0.0037 seconds

# %% [markdown]
# # **Q.40 Train a PCA model and visualize how data points are transformed before and after PCA**

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target
target_names = iris.target_names

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Plot settings
colors = ['red', 'green', 'blue']

# Plot: Original data (first 2 features)
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
for color, i, name in zip(colors, [0, 1, 2], target_names):
    plt.scatter(X[y == i, 0], X[y == i, 1], alpha=0.7, color=color, label=name)
plt.title('Original Data (First 2 Features)')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend()
plt.grid(True)

# Plot: PCA-transformed data (PC1 & PC2)
plt.subplot(1, 2, 2)
for color, i, name in zip(colors, [0, 1, 2], target_names):
    plt.scatter(X_pca[y == i, 0], X_pca[y == i, 1], alpha=0.7, color=color, label=name)
plt.title('PCA-Transformed Data (PC1 vs PC2)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Q.41 Train a KNN Classifier on a real-world dataset (Wine dataset) and print classification report**

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# Load the Wine dataset
wine = load_wine()
X = wine.data
y = wine.target
target_names = wine.target_names

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train KNN Classifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

# Make predictions
y_pred = knn.predict(X_test_scaled)

# Print classification report
print("Classification Report for KNN on Wine Dataset:")
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
# Classification Report for KNN on Wine Dataset:
#               precision    recall  f1-score   support
#
#      class_0       0.95      1.00      0.97        19
#      class_1       1.00      0.90      0.95        21
#      class_2       0.93      1.00      0.97        14
#
#     accuracy                           0.96        54
#    macro avg       0.96      0.97      0.96        54
# weighted avg       0.97      0.96      0.96        54

# %% [markdown]
# # **Q.42 Train a KNN Regressor and analyze the effect of different distance metrics on prediction error**

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

# Generate synthetic regression dataset
X, y = make_regression(n_samples=300, n_features=5, noise=10, random_state=42)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Distance metrics to evaluate
metrics = {
    'euclidean': {'metric': 'minkowski', 'p': 2},
    'manhattan': {'metric': 'manhattan'},
    'minkowski (p=3)': {'metric': 'minkowski', 'p': 3}
}

# Store results
results = {}

# Evaluate each distance metric
for name, params in metrics.items():
    knn = KNeighborsRegressor(n_neighbors=5, **params)
    knn.fit(X_train_scaled, y_train)
    y_pred = knn.predict(X_test_scaled)
    mse = mean_squared_error(y_test, y_pred)
    results[name] = mse

# Print results
print("📊 Mean Squared Error for each Distance Metric:")
for metric, mse in results.items():
    print(f"- {metric}: {mse:.2f}")
# Out:
# 📊 Mean Squared Error for each Distance Metric:
# - euclidean: 1312.12
# - manhattan: 1336.92
# - minkowski (p=3): 1301.83

# %% [markdown]
# # **Q.43Train a KNN Classifier and evaluate using ROC-AUC score**

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# Load binary classification dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Feature scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Train KNN Classifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

# Predict probabilities
y_proba = knn.predict_proba(X_test_scaled)[:, 1]  # Probabilities for the positive class

# Calculate ROC-AUC score
roc_auc = roc_auc_score(y_test, y_proba)
print(f"ROC-AUC Score: {roc_auc:.4f}")

# Plot ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, y_proba)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"KNN (AUC = {roc_auc:.2f})", color='blue')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for KNN Classifier")
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ROC-AUC Score: 0.9787

# %% [markdown]
# # **Q.44 Train a PCA model and visualize the variance captured by each principal component**

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Step 1: Load Wine dataset
data = load_wine()
X = data.data
feature_names = data.feature_names

# Step 2: Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 3: Apply PCA
pca = PCA()
X_pca = pca.fit_transform(X_scaled)

# Step 4: Explained variance ratio and cumulative
explained_variance = pca.explained_variance_ratio_
cumulative_variance = explained_variance.cumsum()

# Step 5: Visualization
plt.figure(figsize=(12, 5))

# Bar plot: Individual explained variance
plt.subplot(1, 2, 1)
plt.bar(range(1, len(explained_variance)+1), explained_variance, color='skyblue', edgecolor='black')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance per Principal Component')
plt.grid(True)

# Line plot: Cumulative explained variance
plt.subplot(1, 2, 2)
plt.plot(range(1, len(cumulative_variance)+1), cumulative_variance, marker='o', linestyle='--', color='green')
plt.axhline(y=0.95, color='r', linestyle=':', label='95% Threshold')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance')
plt.xticks(range(1, len(cumulative_variance)+1))
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Q.45 Train a KNN Classifier and perform feature selection before training**

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score

# Step 1: Load the Wine dataset
data = load_wine()
X = data.data
y = data.target
feature_names = data.feature_names

# Step 2: Feature selection - Select top k features using ANOVA F-test
k = 5  # You can try different values of k
selector = SelectKBest(score_func=f_classif, k=k)
X_selected = selector.fit_transform(X, y)

# Show selected feature names (optional)
selected_feature_names = [feature_names[i] for i in selector.get_support(indices=True)]
print(f"Selected Features ({k}): {selected_feature_names}")

# Step 3: Split data
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.3, random_state=42)

# Step 4: Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 5: Train KNN Classifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

# Step 6: Evaluate
y_pred = knn.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)

print(f"\nAccuracy with top {k} features: {accuracy:.2f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=data.target_names))
# Out:
# Selected Features (5): ['alcohol', 'flavanoids', 'color_intensity', 'od280/od315_of_diluted_wines', 'proline']
#
# Accuracy with top 5 features: 0.98
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      class_0       0.95      1.00      0.97        19
#      class_1       1.00      0.95      0.98        21
#      class_2       1.00      1.00      1.00        14
#
#     accuracy                           0.98        54
#    macro avg       0.98      0.98      0.98        54
# weighted avg       0.98      0.98      0.98        54

# %% [markdown]
# # **Q.46 Train a PCA model and visualize the data reconstruction error after reducing dimensions**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error

# Step 1: Load dataset
data = load_wine()
X = data.data

# Step 2: Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 3: Apply PCA
n_components = 2  # Try different values like 2, 3, 5
pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X_scaled)

# Step 4: Reconstruct data from PCA-reduced version
X_reconstructed = pca.inverse_transform(X_pca)

# Step 5: Compute reconstruction error per sample
reconstruction_errors = np.mean((X_scaled - X_reconstructed) ** 2, axis=1)

# Step 6: Visualize reconstruction error
plt.figure(figsize=(10, 5))
plt.plot(reconstruction_errors, marker='o', linestyle='--', color='crimson')
plt.title(f"Reconstruction Error Per Sample (PCA with {n_components} Components)")
plt.xlabel("Sample Index")
plt.ylabel("Mean Squared Error")
plt.grid(True)
plt.tight_layout()
plt.show()

# Step 7: Print average reconstruction error
mean_error = np.mean(reconstruction_errors)
print(f"🔍 Average Reconstruction Error with {n_components} PCA components: {mean_error:.4f}")
# Out:
# 🔍 Average Reconstruction Error with 2 PCA components: 0.4459

# %% [markdown]
# # **Q.47 Train a KNN Classifier and visualize the decision boundary**

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# Step 1: Load Iris dataset and select two features for 2D visualization
data = load_iris()
X = data.data[:, :2]  # First two features (sepal length and sepal width)
y = data.target

# Step 2: Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Step 3: Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 4: Train KNN Classifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

# Step 5: Create a mesh grid to plot decision boundaries
x_min, x_max = X_train_scaled[:, 0].min() - 1, X_train_scaled[:, 0].max() + 1
y_min, y_max = X_train_scaled[:, 1].min() - 1, X_train_scaled[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

# Step 6: Predict class for each point in the mesh grid
Z = knn.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Step 7: Plot the decision boundary
plt.figure(figsize=(8, 6))
plt.contourf(xx, yy, Z, alpha=0.4, cmap=plt.cm.RdYlBu)

# Step 8: Plot the data points
plt.scatter(X_train_scaled[:, 0], X_train_scaled[:, 1], c=y_train, edgecolors='k', marker='o', cmap=plt.cm.RdYlBu, label="Train Data")
plt.scatter(X_test_scaled[:, 0], X_test_scaled[:, 1], c=y_test, edgecolors='k', marker='^', cmap=plt.cm.RdYlBu, label="Test Data")

plt.title("KNN Classifier Decision Boundary")
plt.xlabel("Sepal Length (Standardized)")
plt.ylabel("Sepal Width (Standardized)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q.48  Train a PCA model and analyze the effect of different numbers of components on data variance

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Step 1: Load the Iris dataset
data = load_iris()
X = data.data
y = data.target

# Step 2: Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 3: Apply PCA for varying numbers of components
n_components_range = range(1, X.shape[1] + 1)  # 1 to 4 components for Iris (4 features)
explained_variances = []
cumulative_variances = []

for n in n_components_range:
    pca = PCA(n_components=n)
    pca.fit(X_scaled)
    explained_variances.append(pca.explained_variance_ratio_)
    cumulative_variances.append(np.cumsum(pca.explained_variance_ratio_))

# Step 4: Plot explained variance for each component
plt.figure(figsize=(14, 6))

# Subplot 1: Explained variance for each component
plt.subplot(1, 2, 1)
for i, ev in enumerate(explained_variances):
    plt.plot(range(1, len(ev) + 1), ev, label=f"{i + 1} components")
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance per Component')
plt.legend()
plt.grid(True)

# Subplot 2: Cumulative explained variance
plt.subplot(1, 2, 2)
for i, cv in enumerate(cumulative_variances):
    plt.plot(range(1, len(cv) + 1), cv, label=f"{i + 1} components")
plt.axhline(y=0.95, color='r', linestyle='--', label='95% Threshold')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
